# %%
pip install --upgrade pip
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 31.4 MB/s eta 0:00:00
# ...
#   Attempting uninstall: pip
#     Found existing installation: pip 24.1.2
#     Uninstalling pip-24.1.2:
#       Successfully uninstalled pip-24.1.2
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# !pip install timm
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 74.6 MB/s  0:00:03
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 100.7 MB/s  0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 106.1 MB/s  0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 35.3 MB/s  0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 50.3 MB/s  0:00:07
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 95.9 MB/s  0:00:02
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 106.4 MB/s  0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 66.9 MB/s  0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 99.4 MB/s  0:00:02
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 133.0 MB/s  0:00:00
# ...
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.5.82
#     Uninstalling nvidia-nvjitlink-cu12-12.5.82:
# ...

# %%
# !pip install -q  pandas openpyxl

# %%
# --- 1. SETUP AND IMPORTS ---
# Install necessary libraries for pre-trained models and reading Excel files

import os
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader
import torchvision.transforms.v2 as transforms
from PIL import Image
import csv # Using the standard CSV library
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, classification_report
import seaborn as sns
from tqdm.notebook import tqdm
import timm # PyTorch Image Models library

# --- 2. CONFIGURATION (Corrected Paths) ---
# Set this to the TOP-LEVEL dataset name from your Kaggle input panel
DATASET_INPUT_NAME = 'newdataset'

# Corrected paths to match your /newdataset/dataset/ structure
BASE_PATH = os.path.join('/kaggle/input/', DATASET_INPUT_NAME, 'dataset')
RAW_PATH = os.path.join(BASE_PATH, 'images/')
SPLIT_PATH = os.path.join(BASE_PATH, 'splits/')

# Model & Training Hyperparameters
DEVICE = "cuda" if torch.cuda.is_available() else "cpu"
IMG_SIZE = 224
BATCH_SIZE = 32
EPOCHS_PER_FOLD = 25
LEARNING_RATE = 3e-5
NUM_FOLDS = 5

# Dataset specific constants
mean = [0.19159977371889528, 0.12109632404575055, 0.11253919439439257]
std = [0.0726453726937946, 0.06086047143439545, 0.05632158600067249]
classes = {
    'normal_esophagus': {'label': 0},
    'esophageal_protruded_lesions': {'label': 1},
    'esophagitis': {'label': 2},
    'barrett_esophagus': {'label': 3},
    'esophageal_cancer': {'label': 4},
}
class_num = len(classes)
class_names = list(classes.keys())


# --- 3. DATASET & TRANSFORMS (CORRECTED LOGIC) ---
train_transform = transforms.Compose([
    transforms.Resize([IMG_SIZE, IMG_SIZE]),
    transforms.RandomHorizontalFlip(p=0.5),
    transforms.RandomRotation(degrees=20),
    transforms.ColorJitter(brightness=0.2, contrast=0.2, saturation=0.2, hue=0.1),
    transforms.ToTensor(),
    transforms.Normalize(mean, std),
])

val_transform = transforms.Compose([
    transforms.Resize([IMG_SIZE, IMG_SIZE]),
    transforms.ToTensor(),
    transforms.Normalize(mean, std),
])

class Esophagus_Dataset(Dataset):
    def __init__(self, raw_path, split_path, task, is_train=True):
        self.raw_path = raw_path
        self.image_files = []
        self.transform = train_transform if is_train else val_transform

        # *** CRITICAL MODIFICATION ***
        # This logic correctly loops through each class folder to find the split CSV file.
        for cl_name, cl_info in classes.items():
            label = cl_info['label']
            # Constructs the correct path, e.g., .../splits/barrett_esophagus/train0.csv
            split_file = os.path.join(split_path, cl_name, task + '.csv')
            
            if not os.path.exists(split_file):
                # This warning is normal for the 'normal_esophagus' class if it has no diseased splits
                # print(f"Info: Split file not found, skipping: {split_file}")
                continue
            
            try:
                with open(split_file, newline='') as f:
                    reader = csv.reader(f)
                    for row in reader:
                        file_name = str(row[0])
                        img_path = os.path.join(self.raw_path, cl_name, file_name)
                        if os.path.exists(img_path):
                            self.image_files.append((img_path, label))
                        else:
                            print(f"Warning: Image file specified in sheet not found at: {img_path}")
            except Exception as e:
                print(f"Error reading {split_file}: {e}")

    def __len__(self):
        return len(self.image_files)

    def __getitem__(self, idx):
        img_path, label = self.image_files[idx]
        image = Image.open(img_path).convert('RGB')
        if self.transform:
            image = self.transform(image)
        return image, label

# --- 4. MODEL DEFINITION ---
def create_vit_model(num_classes=class_num, pretrained=True):
    model = timm.create_model('vit_base_patch16_224.augreg_in21k_ft_in1k', pretrained=pretrained, num_classes=num_classes)
    return model.to(DEVICE)

# --- 5. TRAINING & EVALUATION FUNCTIONS ---
def train_one_epoch(model, dataloader, criterion, optimizer, device):
    model.train()
    running_loss, correct, total = 0.0, 0, 0
    progress_bar = tqdm(dataloader, desc="Training", leave=False)
    for images, labels in progress_bar:
        images, labels = images.to(device), labels.to(device)
        optimizer.zero_grad()
        outputs = model(images)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()
        running_loss += loss.item() * images.size(0)
        _, predicted = torch.max(outputs.data, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()
        progress_bar.set_postfix(loss=loss.item(), acc=f"{(predicted == labels).sum().item()/labels.size(0):.2f}")
    return running_loss / total, 100 * correct / total

def evaluate(model, dataloader, criterion, device):
    model.eval()
    running_loss, correct, total = 0.0, 0, 0
    all_preds, all_labels = [], []
    progress_bar = tqdm(dataloader, desc="Validation", leave=False)
    with torch.no_grad():
        for images, labels in progress_bar:
            images, labels = images.to(device), labels.to(device)
            outputs = model(images)
            loss = criterion(outputs, labels)
            running_loss += loss.item() * images.size(0)
            _, predicted = torch.max(outputs.data, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()
            all_preds.extend(predicted.cpu().numpy())
            all_labels.extend(labels.cpu().numpy())
    return running_loss / total, 100 * correct / total, all_preds, all_labels

def plot_training_curves(history):
    plt.figure(figsize=(12, 5))
    plt.subplot(1, 2, 1)
    plt.plot(history['train_loss'], label='Train Loss')
    plt.plot(history['val_loss'], label='Val Loss')
    plt.legend()
    plt.title('Loss Curves')
    plt.xlabel('Epoch')
    plt.subplot(1, 2, 2)
    plt.plot(history['train_acc'], label='Train Accuracy')
    plt.plot(history['val_acc'], label='Val Accuracy')
    plt.legend()
    plt.title('Accuracy Curves')
    plt.xlabel('Epoch')
    plt.show()

def plot_confusion_matrix(cm, class_names):
    plt.figure(figsize=(10, 8))
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=class_names, yticklabels=class_names)
    plt.title('Confusion Matrix')
    plt.ylabel('True Label')
    plt.xlabel('Predicted Label')
    plt.show()

# --- 6. MAIN K-FOLD CROSS-VALIDATION LOOP ---
print(f"Using device: {DEVICE}")

all_fold_histories = []
fold_accuracies = []
criterion = nn.CrossEntropyLoss()

for fold in range(NUM_FOLDS):
    print(f"\n" + "="*25 + f" FOLD {fold} " + "="*25)
    
    train_task = f'train{fold}'
    val_task = f'val{fold}'
    
    train_dataset = Esophagus_Dataset(RAW_PATH, SPLIT_PATH, task=train_task, is_train=True)
    val_dataset = Esophagus_Dataset(RAW_PATH, SPLIT_PATH, task=val_task, is_train=False)
    
    if len(train_dataset) == 0 or len(val_dataset) == 0:
        print(f"Skipping Fold {fold} due to empty dataset. Please check split file paths and contents.")
        continue

    train_loader = DataLoader(train_dataset, batch_size=BATCH_SIZE, shuffle=True, num_workers=2, pin_memory=True)
    val_loader = DataLoader(val_dataset, batch_size=BATCH_SIZE, shuffle=False, num_workers=2, pin_memory=True)

    print(f"Fold {fold}: Found {len(train_dataset)} training images and {len(val_dataset)} validation images.")
    
    model = create_vit_model()
    optimizer = optim.AdamW(model.parameters(), lr=LEARNING_RATE, weight_decay=0.01)
    scheduler = optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=EPOCHS_PER_FOLD)
    
    best_val_acc = 0.0
    history = {'train_loss': [], 'train_acc': [], 'val_loss': [], 'val_acc': []}
    
    for epoch in range(EPOCHS_PER_FOLD):
        train_loss, train_acc = train_one_epoch(model, train_loader, criterion, optimizer, DEVICE)
        val_loss, val_acc, _, _ = evaluate(model, val_loader, criterion, DEVICE)
        scheduler.step()
        
        print(f"Epoch {epoch+1}/{EPOCHS_PER_FOLD} -> Train Loss: {train_loss:.4f}, Train Acc: {train_acc:.2f}% | Val Loss: {val_loss:.4f}, Val Acc: {val_acc:.2f}%")
        
        history['train_loss'].append(train_loss)
        history['train_acc'].append(train_acc)
        history['val_loss'].append(val_loss)
        history['val_acc'].append(val_acc)
        
        if val_acc > best_val_acc:
            best_val_acc = val_acc
            torch.save(model.state_dict(), f'/kaggle/working/best_model_fold_{fold}.pth')
            print(f"New best model for fold {fold} saved with acc: {val_acc:.2f}%")
    
    fold_accuracies.append(best_val_acc)
    all_fold_histories.append(history)
    print(f"\n--- Best Validation Accuracy for Fold {fold}: {best_val_acc:.2f}% ---")

# --- 7. FINAL RESULTS SUMMARY ---
print("\n" + "="*20 + " Cross-Validation Finished " + "="*20 + "\n")
if fold_accuracies:
    mean_acc = np.mean(fold_accuracies)
    std_acc = np.std(fold_accuracies)
    print(f"Individual Fold Best Accuracies: {[f'{acc:.2f}%' for acc in fold_accuracies]}")
    print(f"Average Validation Accuracy across {NUM_FOLDS} folds: {mean_acc:.2f}%")
    print(f"Standard Deviation of Accuracy: {std_acc:.2f}%")
    
    # --- 8. DETAILED EVALUATION ON THE BEST FOLD ---
    print("\n" + "="*20 + " Detailed Evaluation on Best Fold " + "="*20 + "\n")
    
    best_fold_idx = np.argmax(fold_accuracies)
    print(f"Loading best model from Fold {best_fold_idx} with accuracy {fold_accuracies[best_fold_idx]:.2f}%")
    
    best_model_path = f'/kaggle/working/best_model_fold_{best_fold_idx}.pth'
    best_model = create_vit_model()
    best_model.load_state_dict(torch.load(best_model_path, map_location=DEVICE))
    
    best_fold_history = all_fold_histories[best_fold_idx]
    
    best_val_task = f'val{best_fold_idx}'
    best_val_dataset = Esophagus_Dataset(RAW_PATH, SPLIT_PATH, task=best_val_task, is_train=False)
    best_val_loader = DataLoader(best_val_dataset, batch_size=BATCH_SIZE, shuffle=False, num_workers=2)
    
    final_loss, final_acc, final_preds, final_labels = evaluate(best_model, best_val_loader, criterion, DEVICE)
    print(f"\nBest Fold ({best_fold_idx}) Validation -> Loss: {final_loss:.4f}, Accuracy: {final_acc:.2f}%")
    
    print("\nClassification Report for Best Fold:")
    print(classification_report(final_labels, final_preds, target_names=class_names, zero_division=0))

    print("\nPlotting Training Curves for Best Fold:")
    plot_training_curves(best_fold_history)
    
    print("\nPlotting Confusion Matrix for Best Fold:")
    cm = confusion_matrix(final_labels, final_preds)
    plot_confusion_matrix(cm, class_names)
    
else:
    print("No folds were trained successfully. Please check your file paths and dataset structure.")
# Out:
# /usr/local/lib/python3.11/dist-packages/torchvision/transforms/v2/_deprecated.py:42: UserWarning: The transform `ToTensor()` is deprecated and will be removed in a future release. Instead, please use `v2.Compose([v2.ToImage(), v2.ToDtype(torch.float32, scale=True)])`.Output is equivalent up to float precision.
#   warnings.warn(
# Using device: cuda
#
# ========================= FOLD 0 =========================
# Fold 0: Found 717 training images and 178 validation images.
# model.safetensors:   0%|          | 0.00/346M [00:00<?, ?B/s]
# ...
# Validation:   0%|          | 0/6 [00:00<?, ?it/s]
# Epoch 1/25 -> Train Loss: 1.6438, Train Acc: 48.26% | Val Loss: 1.1108, Val Acc: 57.87%
# New best model for fold 0 saved with acc: 57.87%
# ...
# Validation:   0%|          | 0/6 [00:00<?, ?it/s]
# Epoch 2/25 -> Train Loss: 0.9193, Train Acc: 65.55% | Val Loss: 0.6753, Val Acc: 74.72%
# New best model for fold 0 saved with acc: 74.72%
# ...
# Validation:   0%|          | 0/6 [00:00<?, ?it/s]
# ...
