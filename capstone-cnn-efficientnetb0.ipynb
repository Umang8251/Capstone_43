# %%
# !pip install -q timm pandas openpyxl
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 109.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 85.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 38.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 8.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 15.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 13.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 8.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 83.0 MB/s eta 0:00:00

# %%
# --- 1. SETUP AND IMPORTS ---

import os
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader
import torchvision.transforms.v2 as transforms
from PIL import Image
import csv
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, classification_report
import seaborn as sns
from tqdm.notebook import tqdm
import timm

# --- 2. CONFIGURATION ---
DATASET_INPUT_NAME = 'capdataset'
BASE_PATH = os.path.join('/kaggle/input/', DATASET_INPUT_NAME, 'dataset')
RAW_PATH = os.path.join(BASE_PATH, 'images/')
SPLIT_PATH = os.path.join(BASE_PATH, 'splits/')

# Model & Training Hyperparameters
DEVICE = "cuda" if torch.cuda.is_available() else "cpu"
IMG_SIZE = 224      # EfficientNetB0 is also commonly trained on 224x224
BATCH_SIZE = 32
EPOCHS_PER_FOLD = 25
LEARNING_RATE = 1e-4 # CNNs can often tolerate a slightly higher LR for fine-tuning than ViTs
NUM_FOLDS = 5

# Dataset specific constants (unchanged)
mean = [0.19159977371889528, 0.12109632404575055, 0.11253919439439257]
std = [0.0726453726937946, 0.06086047143439545, 0.05632158600067249]
classes = {
    'normal_esophagus': {'label': 0},
    'esophageal_protruded_lesions': {'label': 1},
    'esophagitis': {'label': 2},
    'barrett_esophagus': {'label': 3},
    'esophageal_cancer': {'label': 4},
}
class_num = len(classes)
class_names = list(classes.keys())

# --- 3. DATASET & TRANSFORMS (Unchanged) ---
train_transform = transforms.Compose([
    transforms.Resize([IMG_SIZE, IMG_SIZE]),
    transforms.RandomHorizontalFlip(p=0.5),
    transforms.RandomRotation(degrees=20),
    transforms.ColorJitter(brightness=0.2, contrast=0.2, saturation=0.2, hue=0.1),
    transforms.ToTensor(),
    transforms.Normalize(mean, std),
])
val_transform = transforms.Compose([
    transforms.Resize([IMG_SIZE, IMG_SIZE]),
    transforms.ToTensor(),
    transforms.Normalize(mean, std),
])

class Esophagus_Dataset(Dataset):
    def __init__(self, raw_path, split_path, task, is_train=True):
        self.raw_path = raw_path
        self.image_files = []
        self.transform = train_transform if is_train else val_transform
        for cl_name, cl_info in classes.items():
            label = cl_info['label']
            split_file = os.path.join(split_path, cl_name, task + '.csv')
            if not os.path.exists(split_file): continue
            try:
                with open(split_file, newline='') as f:
                    reader = csv.reader(f)
                    for row in reader:
                        file_name = str(row[0])
                        img_path = os.path.join(self.raw_path, cl_name, file_name)
                        if os.path.exists(img_path):
                            self.image_files.append((img_path, label))
            except Exception as e:
                print(f"Error reading {split_file}: {e}")
    def __len__(self):
        return len(self.image_files)
    def __getitem__(self, idx):
        img_path, label = self.image_files[idx]
        image = Image.open(img_path).convert('RGB')
        if self.transform:
            image = self.transform(image)
        return image, label

# --- 4. MODEL DEFINITION (MODIFIED FOR EfficientNetB0) ---
def create_cnn_model(num_classes=class_num, pretrained=True):
    """
    Creates a pre-trained EfficientNet-B0 model from the timm library.
    This is a powerful and parameter-efficient CNN, making it a great choice.
    """
    model = timm.create_model(
        'efficientnet_b0',
        pretrained=pretrained,
        num_classes=num_classes
    )
    return model.to(DEVICE)

# --- 5. TRAINING & EVALUATION FUNCTIONS (Unchanged) ---
def train_one_epoch(model, dataloader, criterion, optimizer, device):
    model.train()
    running_loss, correct, total = 0.0, 0, 0
    progress_bar = tqdm(dataloader, desc="Training", leave=False)
    for images, labels in progress_bar:
        images, labels = images.to(device), labels.to(device)
        optimizer.zero_grad()
        outputs = model(images)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()
        running_loss += loss.item() * images.size(0)
        _, predicted = torch.max(outputs.data, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()
        progress_bar.set_postfix(loss=loss.item())
    return running_loss / total, 100 * correct / total

def evaluate(model, dataloader, criterion, device):
    model.eval()
    running_loss, correct, total = 0.0, 0, 0
    all_preds, all_labels = [], []
    progress_bar = tqdm(dataloader, desc="Validation", leave=False)
    with torch.no_grad():
        for images, labels in progress_bar:
            images, labels = images.to(device), labels.to(device)
            outputs = model(images)
            loss = criterion(outputs, labels)
            running_loss += loss.item() * images.size(0)
            _, predicted = torch.max(outputs.data, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()
            all_preds.extend(predicted.cpu().numpy())
            all_labels.extend(labels.cpu().numpy())
    return running_loss / total, 100 * correct / total, all_preds, all_labels

def plot_training_curves(history):
    plt.figure(figsize=(12, 5))
    plt.subplot(1, 2, 1)
    plt.plot(history['train_loss'], label='Train Loss')
    plt.plot(history['val_loss'], label='Val Loss')
    plt.legend()
    plt.title('Loss Curves')
    plt.xlabel('Epoch')
    plt.subplot(1, 2, 2)
    plt.plot(history['train_acc'], label='Train Accuracy')
    plt.plot(history['val_acc'], label='Val Accuracy')
    plt.legend()
    plt.title('Accuracy Curves')
    plt.xlabel('Epoch')
    plt.show()

def plot_confusion_matrix(cm, class_names):
    plt.figure(figsize=(10, 8))
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=class_names, yticklabels=class_names)
    plt.title('Confusion Matrix')
    plt.ylabel('True Label')
    plt.xlabel('Predicted Label')
    plt.show()

# --- 6. MAIN K-FOLD CROSS-VALIDATION LOOP (MODIFIED) ---
print(f"Using device: {DEVICE}")

all_fold_histories = []
fold_accuracies = []
criterion = nn.CrossEntropyLoss()

for fold in range(NUM_FOLDS):
    print(f"\n" + "="*25 + f" FOLD {fold} " + "="*25)
    
    train_task = f'train{fold}'
    val_task = f'val{fold}'
    
    train_dataset = Esophagus_Dataset(RAW_PATH, SPLIT_PATH, task=train_task, is_train=True)
    val_dataset = Esophagus_Dataset(RAW_PATH, SPLIT_PATH, task=val_task, is_train=False)
    
    if len(train_dataset) == 0 or len(val_dataset) == 0:
        print(f"Skipping Fold {fold} due to empty dataset.")
        continue

    train_loader = DataLoader(train_dataset, batch_size=BATCH_SIZE, shuffle=True, num_workers=2, pin_memory=True)
    val_loader = DataLoader(val_dataset, batch_size=BATCH_SIZE, shuffle=False, num_workers=2, pin_memory=True)

    print(f"Fold {fold}: {len(train_dataset)} training images, {len(val_dataset)} validation images.")
    
    # MODIFICATION: Creating the CNN model
    model = create_cnn_model()
    optimizer = optim.AdamW(model.parameters(), lr=LEARNING_RATE, weight_decay=0.01)
    scheduler = optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=EPOCHS_PER_FOLD)
    
    best_val_acc = 0.0
    history = {'train_loss': [], 'train_acc': [], 'val_loss': [], 'val_acc': []}
    
    for epoch in range(EPOCHS_PER_FOLD):
        train_loss, train_acc = train_one_epoch(model, train_loader, criterion, optimizer, DEVICE)
        val_loss, val_acc, _, _ = evaluate(model, val_loader, criterion, DEVICE)
        scheduler.step()
        
        print(f"Epoch {epoch+1}/{EPOCHS_PER_FOLD} -> Train Loss: {train_loss:.4f}, Acc: {train_acc:.2f}% | Val Loss: {val_loss:.4f}, Acc: {val_acc:.2f}%")
        
        history['train_loss'].append(train_loss); history['train_acc'].append(train_acc)
        history['val_loss'].append(val_loss); history['val_acc'].append(val_acc)
        
        if val_acc > best_val_acc:
            best_val_acc = val_acc
            # MODIFICATION: Saving with a different name
            torch.save(model.state_dict(), f'/kaggle/working/best_cnn_model_fold_{fold}.pth')
            print(f"🎉 New best CNN model for fold {fold} saved with acc: {val_acc:.2f}%")
    
    fold_accuracies.append(best_val_acc)
    all_fold_histories.append(history)
    print(f"\n--- Best Validation Accuracy for Fold {fold}: {best_val_acc:.2f}% ---")

# --- 7. FINAL RESULTS SUMMARY ---
print("\n" + "="*20 + " Cross-Validation Finished " + "="*20 + "\n")
if fold_accuracies:
    mean_acc = np.mean(fold_accuracies)
    std_acc = np.std(fold_accuracies)
    print(f"Individual Fold Best Accuracies: {[f'{acc:.2f}%' for acc in fold_accuracies]}")
    print(f"Average Validation Accuracy (CNN): {mean_acc:.2f}%")
    print(f"Standard Deviation of Accuracy: {std_acc:.2f}%")
    
    # --- 8. DETAILED EVALUATION ON THE BEST FOLD (MODIFIED) ---
    print("\n" + "="*20 + " Detailed Evaluation on Best Fold " + "="*20 + "\n")
    
    best_fold_idx = np.argmax(fold_accuracies)
    print(f"Loading best CNN model from Fold {best_fold_idx} with accuracy {fold_accuracies[best_fold_idx]:.2f}%")
    
    # MODIFICATION: Loading the best CNN model
    best_model_path = f'/kaggle/working/best_cnn_model_fold_{best_fold_idx}.pth'
    best_model = create_cnn_model()
    best_model.load_state_dict(torch.load(best_model_path, map_location=DEVICE))
    
    best_fold_history = all_fold_histories[best_fold_idx]
    
    best_val_task = f'val{best_fold_idx}'
    best_val_dataset = Esophagus_Dataset(RAW_PATH, SPLIT_PATH, task=best_val_task, is_train=False)
    best_val_loader = DataLoader(best_val_dataset, batch_size=BATCH_SIZE, shuffle=False, num_workers=2)
    
    final_loss, final_acc, final_preds, final_labels = evaluate(best_model, best_val_loader, criterion, DEVICE)
    print(f"\nBest Fold ({best_fold_idx}) Validation -> Loss: {final_loss:.4f}, Accuracy: {final_acc:.2f}%")
    
    print("\nClassification Report for Best Fold:")
    print(classification_report(final_labels, final_preds, target_names=class_names, zero_division=0))

    print("\nPlotting Training Curves for Best Fold:")
    plot_training_curves(best_fold_history)
    
    print("\nPlotting Confusion Matrix for Best Fold:")
    cm = confusion_matrix(final_labels, final_preds)
    plot_confusion_matrix(cm, class_names)
    
else:
    print("No folds were trained successfully.")
# Out:
# /usr/local/lib/python3.11/dist-packages/torchvision/transforms/v2/_deprecated.py:42: UserWarning: The transform `ToTensor()` is deprecated and will be removed in a future release. Instead, please use `v2.Compose([v2.ToImage(), v2.ToDtype(torch.float32, scale=True)])`.Output is equivalent up to float precision.
#   warnings.warn(
# Using device: cuda
#
# ========================= FOLD 0 =========================
# Fold 0: 717 training images, 178 validation images.
# model.safetensors:   0%|          | 0.00/21.4M [00:00<?, ?B/s]
# Training:   0%|          | 0/23 [00:00<?, ?it/s]
# Validation:   0%|          | 0/6 [00:00<?, ?it/s]
# Epoch 1/25 -> Train Loss: 2.5283, Acc: 42.26% | Val Loss: 1.3257, Acc: 65.17%
# 🎉 New best CNN model for fold 0 saved with acc: 65.17%
# Training:   0%|          | 0/23 [00:00<?, ?it/s]
# Validation:   0%|          | 0/6 [00:00<?, ?it/s]
# Epoch 2

# Training:   0%|          | 0/23 [00:00<?, ?it/s]
# Validation:   0%|          | 0/6 [00:00<?, ?it/s]
# Epoch 6/25 -> Train Loss: 0.2722, Acc: 90.79% | Val Loss: 0.4709, Acc: 82.02%
# 🎉 New best CNN model for fold 3 saved with acc: 82.02%
# Training:   0%|          | 0/23 [00:00<?, ?it/s]
# Validation:   0%|          | 0/6 [00:00<?, ?it/s]
# Epoch 7/25 -> Train Loss: 0.1927, Acc: 94.56% | Val Loss: 0.4903, Acc: 83.15%
# 🎉 New best CNN model for fold 3 saved with acc: 83.15%
# Training:   0%|          | 0/23 [00:00<?, ?it/s]
# Validation:   0%|          | 0/6 [00:00<?, ?it/s]
# Epoch 8/25 -> Train Loss: 0.2231, Acc: 93.03% | Val Loss: 0.4516, Acc: 84.83%
# 🎉 New best CNN model for fold 3 saved with acc: 84.83%
# Training:   0%|          | 0/23 [00:00<?, ?it/s]
# Validation:   0%|          | 0/6 [00:00<?, ?it/s]
# Epoch 9/25 -> Train Loss: 0.1520, Acc: 94.70% | Val Loss: 0.4505, Acc: 85.39%
# 🎉 New best CNN model for fold 3 saved with acc: 85.39%
# Training:   0%|          | 0/23 [00:00<?, ?it/s]
# Validation:   0%|          | 0/6 [00:00<?, ?it/s]
# Epoch 10/25 -> Train Loss: 0.1443, Acc: 95.82% | Val Loss: 0.4226, Acc: 84.27%
# Training:   0%|          | 0/23 [00:00<?, ?it/s]
# Validation:   0%|          | 0/6 [00:00<?, ?it/s]
# Epoch 11/25 -> Train Loss: 0.1102, Acc: 96.37% | Val Loss: 0.4736, Acc: 84.27%
# Training:   0%|          | 0/23 [00:00<?, ?it/s]
# Validation:   0%|          | 0/6 [00:00<?, ?it/s]
# Epoch 12/25 -> Train Loss: 0.1145, Acc: 95.96% | Val Loss: 0.4293, Acc: 85.39%
# Training:   0%|          | 0/23 [00:00<?, ?it/s]
# Validation:   0%|          | 0/6 [00:00<?, ?it/s]
# Epoch 13/25 -> Train Loss: 0.0887, Acc: 97.35% | Val Loss: 0.4212, Acc: 85.39%
# Training:   0%|          | 0/23 [00:00<?, ?it/s]
# Validation:   0%|          | 0/6 [00:00<?, ?it/s]
# Epoch 14/25 -> Train Loss: 0.0851, Acc: 97.21% | Val Loss: 0.4467, Acc: 85.39%
# Training:   0%|          | 0/23 [00:00<?, ?it/s]
# Validation:   0%|          | 0/6 [00:00<?, ?it/s]
# Epoch 15/25 -> Train Loss: 0.0698, Acc: 97.63% | Val Loss: 0.4090, Acc: 87.08%
# 🎉 New best CNN model for fold 3 saved with acc: 87.08%
# Training:   0%|          | 0/23 [00:00<?, ?it/s]
# Validation:   0%|          | 0/6 [00:00<?, ?it/s]
# Epoch 16/25 -> Train Loss: 0.0996, Acc: 96.37% | Val Loss: 0.4201, Acc: 84.83%
# Training:   0%|          | 0/23 [00:00<?, ?it/s]
# Validation:   0%|          | 0/6 [00:00<?, ?it/s]
# Epoch 17/25 -> Train Loss: 0.0568, Acc: 98.47% | Val Loss: 0.4158, Acc: 84.27%
# Training:   0%|          | 0/23 [00:00<?, ?it/s]
# Validation:   0%|          | 0/6 [00:00<?, ?it/s]
# Epoch 18/25 -> Train Loss: 0.0699, Acc: 97.35% | Val Loss: 0.3978, Acc: 85.96%
# Training:   0%|          | 0/23 [00:00<?, ?it/s]
# Validation:   0%|          | 0/6 [00:00<?, ?it/s]
# Epoch 19/25 -> Train Loss: 0.0806, Acc: 97.07% | Val Loss: 0.3979, Acc: 84.83%
# Training:   0%|          | 0/23 [00:00<?, ?it/s]
# Validation:   0%|          | 0/6 [00:00<?, ?it/s]
# Epoch 20/25 -> Train Loss: 0.0470, Acc: 98.33% | Val Loss: 0.4143, Acc: 85.39%
# Training:   0%|          | 0/23 [00:00<?, ?it/s]
# Validation:   0%|          | 0/6 [00:00<?, ?it/s]
# Epoch 21/25 -> Train Loss: 0.0742, Acc: 96.65% | Val Loss: 0.4122, Acc: 84.83%
# Training:   0%|          | 0/23 [00:00<?, ?it/s]
# Validation:   0%|          | 0/6 [00:00<?, ?it/s]
# Epoch 22/25 -> Train Loss: 0.0736, Acc: 97.91% | Val Loss: 0.4326, Acc: 84.83%
# Training:   0%|          | 0/23 [00:00<?, ?it/s]
# Validation:   0%|          | 0/6 [00:00<?, ?it/s]
# Epoch 23/25 -> Train Loss: 0.0544, Acc: 98.88% | Val Loss: 0.4008, Acc: 86.52%
# Training:   0%|          | 0/23 [00:00<?, ?it/s]
# Validation:   0%|          | 0/6 [00:00<?, ?it/s]
# Epoch 24/25 -> Train Loss: 0.0419, Acc: 98.05% | Val Loss: 0.4385, Acc: 85.39%
# Training:   0%|          | 0/23 [00:00<?, ?it/s]
# Validation:   0%|          | 0/6 [00:00<?, ?it/s]
# Epoch 25/25 -> Train Loss: 0.0574, Acc: 97.91% | Val Loss: 0.4150, Acc: 85.39%
#
# --- Best Validation Accuracy for Fold 3: 87.08% ---
#
# ========================= FOLD 4 =========================
# Fold 4: 712 training images, 183 validation images.
# Training:   0%|          | 0/23 [00:00<?, ?it/s]
# Validation:   0%|          | 0/6 [00:00<?, ?it/s]
# Epoch 1/25 -> Train Loss: 2.2086, Acc: 43.68% | Val Loss: 1.9792, Acc: 53.55%
# 🎉 New best CNN model for fold 4 saved with acc: 53.55%
# Training:   0%|          | 0/23 [00:00<?, ?it/s]
# Validation:   0%|          | 0/6 [00:00<?, ?it/s]
# Epoch 2/25 -> Train Loss: 1.0148, Acc: 71.21% | Val Loss: 1.3293, Acc: 60.11%
# 🎉 New best CNN model for fold 4 saved with acc: 60.11%
# Training:   0%|          | 0/23 [00:00<?, ?it/s]
# Validation:   0%|          | 0/6 [00:00<?, ?it/s]
# Epoch 3/25 -> Train Loss: 0.6200, Acc: 79.49% | Val Loss: 1.0561, Acc: 68.85%
# 🎉 New best CNN model for fold 4 saved with acc: 68.85%
# Training:   0%|          | 0/23 [00:00<?, ?it/s]
# Validation:   0%|          | 0/6 [00:00<?, ?it/s]
# Epoch 4/25 -> Train Loss: 0.4510, Acc: 84.55% | Val Loss: 1.0236, Acc: 72.13%
# 🎉 New best CNN model for fold 4 saved with acc: 72.13%
# Training:   0%|          | 0/23 [00:00<?, ?it/s]
# Validation:   0%|          | 0/6 [00:00<?, ?it/s]
# Epoch 5/25 -> Train Loss: 0.3651, Acc: 86.94% | Val Loss: 0.9365, Acc: 74.32%
# 🎉 New best CNN model for fold 4 saved with acc: 74.32%
# Training:   0%|          | 0/23 [00:00<?, ?it/s]
# Validation:   0%|          | 0/6 [00:00<?, ?it/s]
# Epoch 6/25 -> Train Loss: 0.3275, Acc: 89.75% | Val Loss: 0.8282, Acc: 76.50%
# 🎉 New best CNN model for fold 4 saved with acc: 76.50%
# Training:   0%|          | 0/23 [00:00<?, ?it/s]
# Validation:   0%|          | 0/6 [00:00<?, ?it/s]
# Epoch 7/25 -> Train Loss: 0.2463, Acc: 91.29% | Val Loss: 0.8273, Acc: 79.23%
# 🎉 New best CNN model for fold 4 saved with acc: 79.23%
# Training:   0%|          | 0/23 [00:00<?, ?it/s]
# Validation:   0%|          | 0/6 [00:00<?, ?it/s]
# Epoch 8/25 -> Train Loss: 0.1765, Acc: 94.52% | Val Loss: 0.8539, Acc: 78.69%
# Training:   0%|          | 0/23 [00:00<?, ?it/s]
# Validation:   0%|          | 0/6 [00:00<?, ?it/s]
# Epoch 9/25 -> Train Loss: 0.1720, Acc: 93.12% | Val Loss: 0.8082, Acc: 77.05%
# Training:   0%|          | 0/23 [00:00<?, ?it/s]
# Validation:   0%|          | 0/6 [00:00<?, ?it/s]
# Epoch 10/25 -> Train Loss: 0.1275, Acc: 95.79% | Val Loss: 0.7595, Acc: 80.33%
# 🎉 New best CNN model for fold 4 saved with acc: 80.33%
# Training:   0%|          | 0/23 [00:00<?, ?it/s]
# Validation:   0%|          | 0/6 [00:00<?, ?it/s]
# Epoch 11/25 -> Train Loss: 0.1254, Acc: 95.37% | Val Loss: 0.7600, Acc: 79.23%
# Training:   0%|          | 0/23 [00:00<?, ?it/s]
# Validation:   0%|          | 0/6 [00:00<?, ?it/s]
# Epoch 12/25 -> Train Loss: 0.1297, Acc: 95.51% | Val Loss: 0.7117, Acc: 79.78%
# Training:   0%|          | 0/23 [00:00<?, ?it/s]
# Validation:   0%|          | 0/6 [00:00<?, ?it/s]
# Epoch 13/25 -> Train Loss: 0.0974, Acc: 96.35% | Val Loss: 0.6997, Acc: 79.78%
# Training:   0%|          | 0/23 [00:00<?, ?it/s]
# Validation:   0%|          | 0/6 [00:00<?, ?it/s]
# Epoch 14/25 -> Train Loss: 0.1105, Acc: 95.79% | Val Loss: 0.7248, Acc: 81.42%
# 🎉 New best CNN model for fold 4 saved with acc: 81.42%
# Training:   0%|          | 0/23 [00:00<?, ?it/s]
# Validation:   0%|          | 0/6 [00:00<?, ?it/s]
# Epoch 15/25 -> Train Loss: 0.1265, Acc: 95.51% | Val Loss: 0.7094, Acc: 84.15%
# 🎉 New best CNN model for fold 4 saved with acc: 84.15%
# Training:   0%|          | 0/23 [00:00<?, ?it/s]
# Validation:   0%|          | 0/6 [00:00<?, ?it/s]
# Epoch 16/25 -> Train Loss: 0.0666, Acc: 97.75% | Val Loss: 0.6767, Acc: 81.97%
# Training:   0%|          | 0/23 [00:00<?, ?it/s]
# Validation:   0%|          | 0/6 [00:00<?, ?it/s]
# Epoch 17/25 -> Train Loss: 0.0635, Acc: 98.17% | Val Loss: 0.6874, Acc: 81.97%
# Training:   0%|          | 0/23 [00:00<?, ?it/s]
# Validation:   0%|          | 0/6 [00:00<?, ?it/s]
# Epoch 18/25 -> Train Loss: 0.0698, Acc: 97.47% | Val Loss: 0.6616, Acc: 82.51%
# Training:   0%|          | 0/23 [00:00<?, ?it/s]
# Validation:   0%|          | 0/6 [00:00<?, ?it/s]
# Epoch 19/25 -> Train Loss: 0.0565, Acc: 98.17% | Val Loss: 0.6434, Acc: 82.51%
# Training:   0%|          | 0/23 [00:00<?, ?it/s]
# Validation:   0%|          | 0/6 [00:00<?, ?it/s]
# Epoch 20/25 -> Train Loss: 0.0760, Acc: 97.05% | Val Loss: 0.6157, Acc: 81.97%
# Training:   0%|          | 0/23 [00:00<?, ?it/s]
# Validation:   0%|          | 0/6 [00:00<?, ?it/s]
# Epoch 21/25 -> Train Loss: 0.0978, Acc: 96.77% | Val Loss: 0.6719, Acc: 83.61%
# Training:   0%|          | 0/23 [00:00<?, ?it/s]
# Validation:   0%|          | 0/6 [00:00<?, ?it/s]
# Epoch 22/25 -> Train Loss: 0.0732, Acc: 97.33% | Val Loss: 0.6119, Acc: 82.51%
# Training:   0%|          | 0/23 [00:00<?, ?it/s]
# Validation:   0%|          | 0/6 [00:00<?, ?it/s]
# Epoch 23/25 -> Train Loss: 0.0834, Acc: 97.47% | Val Loss: 0.6391, Acc: 81.97%
# Training:   0%|          | 0/23 [00:00<?, ?it/s]
# Validation:   0%|          | 0/6 [00:00<?, ?it/s]
# Epoch 24/25 -> Train Loss: 0.0753, Acc: 96.91% | Val Loss: 0.6164, Acc: 81.97%
# Training:   0%|          | 0/23 [00:00<?, ?it/s]
# Validation:   0%|          | 0/6 [00:00<?, ?it/s]
# Epoch 25/25 -> Train Loss: 0.0895, Acc: 97.33% | Val Loss: 0.6336, Acc: 80.87%
#
# --- Best Validation Accuracy for Fold 4: 84.15% ---
#
# ==================== Cross-Validation Finished ====================
#
# Individual Fold Best Accuracies: ['89.89%', '85.39%', '91.01%', '87.08%', '84.15%']
# Average Validation Accuracy (CNN): 87.50%
# Standard Deviation of Accuracy: 2.60%
#
# ==================== Detailed Evaluation on Best Fold ====================
#
# Loading best CNN model from Fold 2 with accuracy 91.01%
# Validation:   0%|          | 0/6 [00:00<?, ?it/s]
# Best Fold (2) Validation -> Loss: 0.4213, Accuracy: 91.01%
#
# Classification Report for Best Fold:
#                               precision    recall  f1-score   support
#
#             normal_esophagus       0.87      0.98      0.92        42
# esophageal_protruded_lesions       0.91      0.81      0.85        36
#                  esophagitis       1.00      0.84      0.91        25
#            barrett_esophagus       0.85      0.73      0.79        15
#            esophageal_cancer       0.92      1.00      0.96        60
#
#                     accuracy                           0.91       178
#                    macro avg       0.91      0.87      0.89       178
#                 weighted avg       0.91      0.91      0.91       178
#
#
# Plotting Training Curves for Best Fold:
# Plotting Confusion Matrix for Best Fold:
